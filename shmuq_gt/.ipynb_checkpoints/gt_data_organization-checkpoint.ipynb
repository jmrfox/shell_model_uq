# %%
import numpy as np

import os
from glob import glob
from tqdm import tqdm

def optimal_n_bins(y,max_bins=100):
    from scipy.stats import iqr
    n_bins = int((max(y) - min(y))/(2*iqr(y)*len(y)**(-1/3)))
    return min(n_bins,max_bins)

import matplotlib
import matplotlib.pyplot as plt
font = {'family' : 'serif',
        'weight' : 'normal',
        'size'   : 18}
matplotlib.rc('font', **font)

import pandas as pd
import pickle as pkl

from hepstats.modeling import bayesian_blocks

# %%
path_to_usdb_csv = './sd_GT_usdb.csv'
df_usdb = pd.read_csv(path_to_usdb_csv)

# %%
usdbmil = np.loadtxt('/p/lustre2/fox39/shmuq/usdb/shmuq_gt/usdbmil.vec',skiprows=1)
usdb = np.loadtxt('/p/lustre2/fox39/shmuq/usdb/shmuq_gt/usdb.vec',skiprows=1)

# %%
n_transitions = len(df_usdb[df_usdb['include']==True])
print('# transitions =', n_transitions)
# Out:
# # transitions = 185

# %%
gA = 1.28

df_usdb['Bth_gA2'] = df_usdb['Bth']*gA**2
df_usdb['Berr_gA2'] = df_usdb['Bexp']-df_usdb['Bth_gA2']-1.0*df_usdb['Tmirror']
df_usdb['Berr'] = df_usdb['Bexp']-df_usdb['Bth']-1.0*df_usdb['Tmirror']

# %% [markdown]
# Simply using $g_A$ at the free-nucleon value, unquenched, we have this distribution of absolute errors for B(GT)

# %%
y = np.array(df_usdb['Bth_gA2'])
plt.hist(y, bins=optimal_n_bins(y), density=True)
plt.title(f'Bth')
plt.xlabel('Bth')
plt.show()

y = np.array(df_usdb['Bexp'])
plt.hist(y, bins=optimal_n_bins(y), density=True)
plt.title(f'Bexp')
plt.xlabel('Bexp')
plt.show()

y = np.array(df_usdb['Bexp'] - df_usdb['Bth_gA2'])
plt.hist(y, bins=optimal_n_bins(y), density=True)
plt.title(f'Bexp - Bth')
plt.xlabel('Bexp - Bth')
plt.show()

y = np.array(df_usdb['Bth_gA2'] / df_usdb['Bexp'])
plt.hist(y, bins=optimal_n_bins(y), density=True)
plt.title(f'Quotient histogram (gA = {gA})')
plt.xlabel('Bth / Bexp')
plt.show()

# %%
from scipy.optimize import minimize

def objective(dBap,q,df):
    chi_squared = np.sum((df['Bexp']-q**2*df['Bth_gA2']-1.0*df['Tmirror'])**2/(df['sigma_B']**2 + dBap**2)) 
    dof = n_transitions - 1
    return (chi_squared/dof - 1)**2

dBap = minimize(objective,x0=0.5,args=(0.77,df_usdb),bounds=[(0,10000)]).x[0]

# %%
print('a priori B(GT) std. dev. =', dBap)
print('a priori B(GT) variance =', dBap**2)
# Out:
# a priori B(GT) std. dev. = 0.5
# a priori B(GT) variance = 0.25

# %%
df_usdb['Bresid'] = df_usdb['Berr']/np.sqrt(df_usdb['sigma_B']**2 + dBap**2)
df_usdb['Bresid_gA2'] = (df_usdb['Bexp']-df_usdb['Bth_gA2']-1.0*df_usdb['Tmirror'])/np.sqrt(df_usdb['sigma_B']**2 + dBap**2)

# %%
# data_path = '/p/lustre2/fox39/shmuq/usdb/shmuq_gt/batch_results'
# run_dir_list = []
# for batch_dir in sorted(glob(os.path.join(data_path,'batch_job*'))):
# #     print(batch_dir)
#     for run_dir in sorted(glob(os.path.join(batch_dir,'run_usdb_rand?????'))):
#         run_dir_list.append(run_dir)
#         print(run_dir)

#not organized by run directory anymore, just each csv file in batch_dir 
data_path = '/p/lustre2/fox39/shmuq/usdb/shmuq_gt/batch_results'
df_dict = {}
problem_cases = []
for batch_dir in tqdm(sorted(glob(os.path.join(data_path,'batch_job*')))):
#     print(batch_dir)
    for csv_path in sorted(glob(os.path.join(batch_dir,'sd_GT_usdb_rand?????.csv'))):
        csv_name = os.path.split(csv_path)[-1]
        print(csv_name)
        int_vec_name = csv_name[6:].replace('.csv','.vec')
        print(int_vec_name)
        mil_vec_name = int_vec_name.replace('usdb','usdbmil')
        print(mil_vec_name)
        run_num_string = int_vec_name.split('rand')[-1][:-4]
        print(run_num_string)
        
        try:
            df_dict[run_num_string] = [pd.read_csv(os.path.join(batch_dir,csv_name)), 
                                   np.loadtxt(os.path.join(batch_dir,int_vec_name),skiprows=1), 
                                   np.loadtxt(os.path.join(batch_dir,mil_vec_name),skiprows=1)]
        except OSError:
            problem_cases.append(run_num_string)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# sd_GT_usdb_rand00001.csv
# usdb_rand00001.vec
# usdbmil_rand00001.vec
# 00001
# sd_GT_usdb_rand00002.csv
# usdb_rand00002.vec
# usdbmil_rand00002.vec
# 00002
# sd_GT_usdb_rand00003.csv
# usdb_rand00003.vec
# usdbmil_rand00003.vec
# 00003
# sd_GT_usdb_rand00004.csv
# usdb_rand00004.vec
# usdbmil_rand00004.vec
# 00004
# sd_GT_usdb_rand00005.csv
# usdb_rand00005.vec
# usdbmil_rand00005.vec
# 00005
# sd_GT_usdb_rand00006.csv
# usdb_rand00006.vec
# usdbmil_rand00006.vec
# 00006
# sd_GT_usdb_rand00007.csv
# usdb_rand00007.vec
# usdbmil_rand00007.vec
# 00007
# sd_GT_usdb_rand00008.csv
# usdb_rand00008.vec
# usdbmil_rand00008.vec
# 00008
# sd_GT_usdb_rand00009.csv
# usdb_rand00009.vec
# usdbmil_rand00009.vec
# 00009
# sd_GT_usdb_rand00010.csv
# usdb_rand00010.vec
# usdbmil_rand00010.vec
# 00010
# sd_GT_usdb_rand00011.csv
# usdb_rand00011.vec
# usdbmil_rand00011.vec
# 00011
# sd_GT_usdb_rand00012.csv
# usdb_rand00012.vec
# usdbmil_rand00012.vec
# 00012
# sd_GT_usdb_rand00013.csv
# usdb_rand00013.vec
# usdbmil_rand00013.vec
# 00013
# sd_GT_usdb_rand00014.csv
# usdb_rand00014.vec
# usdbmil_rand00014.vec
# 00014
# sd_GT_usdb_rand00015.csv
# usdb_rand00015.vec
# usdbmil_rand00015.vec
# 00015
# sd_GT_usdb_rand00016.csv
# usdb_rand00016.vec
# usdbmil_rand00016.vec
# 00016
# sd_GT_usdb_rand00017.csv
# usdb_rand00017.vec
# usdbmil_rand00017.vec
# 00017
# sd_GT_usdb_rand00018.csv
# usdb_rand00018.vec
# usdbmil_rand00018.vec
# 00018
# sd_GT_usdb_rand00019.csv
# usdb_rand00019.vec
# usdbmil_rand00019.vec
# 00019
# sd_GT_usdb_rand00020.csv
# usdb_rand00020.vec
# usdbmil_rand00020.vec
# 00020
#   6%|▋         | 65/1000 [00:00<00:09, 101.21it/s]
# sd_GT_usdb_rand01001.csv
# usdb_rand01001.vec
# usdbmil_rand01001.vec
# 01001
# sd_GT_usdb_rand01002.csv
# usdb_rand01002.vec
# usdbmil_rand01002.vec
# 01002
# sd_GT_usdb_rand01003.csv
# usdb_rand01003.vec
# usdbmil_rand01003.vec
# 01003
# sd_GT_usdb_rand01004.csv
# usdb_rand01004.vec
# usdbmil_rand01004.vec
# 01004
# sd_GT_usdb_rand01005.csv
# usdb_rand01005.vec
# usdbmil_rand01005.vec
# 01005
# sd_GT_usdb_rand01006.csv
# usdb_rand01006.vec
# usdbmil_rand01006.vec
# 01006
# sd_GT_usdb_rand01007.csv
# usdb_rand01007.vec
# usdbmil_rand01007.vec
# 01007
# sd_GT_usdb_rand01008.csv
# usdb_rand01008.vec
# usdbmil_rand01008.vec
# 01008
# sd_GT_usdb_rand01009.csv
# usdb_rand01009.vec
# usdbmil_rand01009.vec
# 01009
# sd_GT_usdb_rand01010.csv
# usdb_rand01010.vec
# usdbmil_rand01010.vec
# 01010
# sd_GT_usdb_rand01011.csv
# usdb_rand01011.vec
# usdbmil_rand01011.vec
# 01011
# sd_GT_usdb_rand01012.csv
# usdb_rand01012.vec
# usdbmil_rand01012.vec
# 01012
# sd_GT_usdb_rand01013.csv
# usdb_rand01013.vec
# usdbmil_rand01013.vec
# 01013
# sd_GT_usdb_rand01014.csv
# usdb_rand01014.vec
# usdbmil_rand01014.vec
# 01014
# sd_GT_usdb_rand01015.csv
# usdb_rand01015.vec
# usdbmil_rand01015.vec
# 01015
# sd_GT_usdb_rand01016.csv
# usdb_rand01016.vec
# usdbmil_rand01016.vec
# 01016
# sd_GT_usdb_rand01017.csv
# usdb_rand01017.vec
# usdbmil_rand01017.vec
# 01017
# sd_GT_usdb_rand01018.csv
# usdb_rand01018.vec
# usdbmil_rand01018.vec
# 01018
# sd_GT_usdb_rand01019.csv
# usdb_rand01019.vec
# usdbmil_rand01019.vec
# 01019
# sd_GT_usdb_rand01020.csv
# usdb_rand01020.vec
# usdbmil_rand01020.vec
# 01020
#  10%|█         | 102/1000 [00:08<01:33,  9.60it/s]
# sd_GT_usdb_rand01021.csv
# usdb_rand01021.vec
# usdbmil_rand01021.vec
# 01021
# sd_GT_usdb_rand01022.csv
# usdb_rand01022.vec
# usdbmil_rand01022.vec
# 01022
# sd_GT_usdb_rand01023.csv
# usdb_rand01023.vec
# usdbmil_rand01023.vec
# 01023
# sd_GT_usdb_rand01024.csv
# usdb_rand01024.vec
# usdbmil_rand01024.vec
# 01024
# sd_GT_usdb_rand01025.csv
# usdb_rand01025.vec
# usdbmil_rand01025.vec
# 01025
# sd_GT_usdb_rand01026.csv
# usdb_rand01026.vec
# usdbmil_rand01026.vec
# 01026
# sd_GT_usdb_rand01027.csv
# usdb_rand01027.vec
# usdbmil_rand01027.vec
# 01027
# sd_GT_usdb_rand01028.csv
# usdb_rand01028.vec
# usdbmil_rand01028.vec
# 01028
# sd_GT_usdb_rand01029.csv
# usdb_rand01029.vec
# usdbmil_rand01029.vec
# 01029
# sd_GT_usdb_rand01030.csv
# usdb_rand01030.vec
# usdbmil_rand01030.vec
# 01030
# sd_GT_usdb_rand01031.csv
# usdb_rand01031.vec
# usdbmil_rand01031.vec
# 01031
# sd_GT_usdb_rand01032.csv
# usdb_rand01032.vec
# usdbmil_rand01032.vec
# 01032
# sd_GT_usdb_rand01033.csv
# usdb_rand01033.vec
# usdbmil_rand01033.vec
# 01033
# sd_GT_usdb_rand01034.csv
# usdb_rand01034.vec
# usdbmil_rand01034.vec
# 01034
# sd_GT_usdb_rand01035.csv
# usdb_rand01035.vec
# usdbmil_rand01035.vec
# 01035
# sd_GT_usdb_rand01036.csv
# usdb_rand01036.vec
# usdbmil_rand01036.vec
# 01036
# sd_GT_usdb_rand01037.csv
# usdb_rand01037.vec
# usdbmil_rand01037.vec
# 01037
# sd_GT_usdb_rand01038.csv
# usdb_rand01038.vec
# usdbmil_rand01038.vec
# 01038
# sd_GT_usdb_rand01039.csv
# usdb_rand01039.vec
# usdbmil_rand01039.vec
# 01039
# sd_GT_usdb_rand01040.csv
# usdb_rand01040.vec
# usdbmil_rand01040.vec
# 01040
# sd_GT_usdb_rand01041.csv
# usdb_rand01041.vec
# usdbmil_rand01041.vec
# 01041
# sd_GT_usdb_rand01042.csv
# usdb_rand01042.vec
# usdbmil_rand01042.vec
# 01042
# sd_GT_usdb_rand01043.csv
# usdb_rand01043.vec
# usdbmil_rand01043.vec
# 01043
# sd_GT_usdb_rand01044.csv
# usdb_rand01044.vec
# usdbmil_rand01044.vec
# 01044
# sd_GT_usdb_rand01045.csv
# usdb_rand01045.vec
# usdbmil_rand01045.vec
# 01045
# sd_GT_usdb_rand01046.csv
# usdb_rand01046.vec
# usdbmil_rand01046.vec
# 01046
# sd_GT_usdb_rand01047.csv
# usdb_rand01047.vec
# usdbmil_rand01047.vec
# 01047
# sd_GT_usdb_rand01048.csv
# usdb_rand01048.vec
# usdbmil_rand01048.vec
# 01048
# sd_GT_usdb_rand01049.csv
# usdb_rand01049.vec
# usdbmil_rand01049.vec
# 01049
# sd_GT_usdb_rand01050.csv
# usdb_rand01050.vec
# usdbmil_rand01050.vec
# 01050
#  10%|█         | 102/1000 [00:19<01:33,  9.60it/s]
# sd_GT_usdb_rand01051.csv
# usdb_rand01051.vec
# usdbmil_rand01051.vec
# 01051
# sd_GT_usdb_rand01052.csv
# usdb_rand01052.vec
# usdbmil_rand01052.vec
# 01052
# sd_GT_usdb_rand01053.csv
# usdb_rand01053.vec
# usdbmil_rand01053.vec
# 01053
# sd_GT_usdb_rand01054.csv
# usdb_rand01054.vec
# usdbmil_rand01054.vec
# 01054
# sd_GT_usdb_rand01055.csv
# usdb_rand01055.vec
# usdbmil_rand01055.vec
# 01055
# sd_GT_usdb_rand01056.csv
# usdb_rand01056.vec
# usdbmil_rand01056.vec
# 01056
# sd_GT_usdb_rand01057.csv
# usdb_rand01057.vec
# usdbmil_rand01057.vec
# 01057
# sd_GT_usdb_rand01058.csv
# usdb_rand01058.vec
# usdbmil_rand01058.vec
# 01058
# sd_GT_usdb_rand01059.csv
# usdb_rand01059.vec
# usdbmil_rand01059.vec
# 01059
# sd_GT_usdb_rand01060.csv
# usdb_rand01060.vec
# usdbmil_rand01060.vec
# 01060
#  11%|█         | 106/1000 [00:23<04:58,  2.99it/s]
# sd_GT_usdb_rand01061.csv
# usdb_rand01061.vec
# usdbmil_rand01061.vec
# 01061
# sd_GT_usdb_rand01062.csv
# usdb_rand01062.vec
# usdbmil_rand01062.vec
# 01062
# sd_GT_usdb_rand01063.csv
# usdb_rand01063.vec
# usdbmil_rand01063.vec
# 01063
# sd_GT_usdb_rand01064.csv
# usdb_rand01064.vec
# usdbmil_rand01064.vec
# 01064
# sd_GT_usdb_rand01065.csv
# usdb_rand01065.vec
# usdbmil_rand01065.vec
# 01065
# sd_GT_usdb_rand01066.csv
# usdb_rand01066.vec
# usdbmil_rand01066.vec
# 01066
# sd_GT_usdb_rand01067.csv
# usdb_rand01067.vec
# usdbmil_rand01067.vec
# 01067
# sd_GT_usdb_rand01068.csv
# usdb_rand01068.vec
# usdbmil_rand01068.vec
# 01068
# sd_GT_usdb_rand01069.csv
# usdb_rand01069.vec
# usdbmil_rand01069.vec
# 01069
# sd_GT_usdb_rand01070.csv
# usdb_rand01070.vec
# usdbmil_rand01070.vec
# 01070
#  11%|█         | 107/1000 [00:26<06:01,  2.47it/s]
# sd_GT_usdb_rand01071.csv
# usdb_rand01071.vec
# usdbmil_rand01071.vec
# 01071
# sd_GT_usdb_rand01072.csv
# usdb_rand01072.vec
# usdbmil_rand01072.vec
# 01072
# sd_GT_usdb_rand01073.csv
# usdb_rand01073.vec
# usdbmil_rand01073.vec
# 01073
# sd_GT_usdb_rand01074.csv
# usdb_rand01074.vec
# usdbmil_rand01074.vec
# 01074
# sd_GT_usdb_rand01075.csv
# usdb_rand01075.vec
# usdbmil_rand01075.vec
# 01075
# sd_GT_usdb_rand01076.csv
# usdb_rand01076.vec
# usdbmil_rand01076.vec
# 01076
# sd_GT_usdb_rand01077.csv
# usdb_rand01077.vec
# usdbmil_rand01077.vec
# 01077
# sd_GT_usdb_rand01078.csv
# usdb_rand01078.vec
# usdbmil_rand01078.vec
# 01078
# sd_GT_usdb_rand01079.csv
# usdb_rand01079.vec
# usdbmil_rand01079.vec
# 01079
# sd_GT_usdb_rand01080.csv
# usdb_rand01080.vec
# usdbmil_rand01080.vec
# 01080
# sd_GT_usdb_rand01081.csv
# usdb_rand01081.vec
# usdbmil_rand01081.vec
# 01081
# sd_GT_usdb_rand01082.csv
# usdb_rand01082.vec
# usdbmil_rand01082.vec
# 01082
# sd_GT_usdb_rand01083.csv
# usdb_rand01083.vec
# usdbmil_rand01083.vec
# 01083
# sd_GT_usdb_rand01084.csv
# usdb_rand01084.vec
# usdbmil_rand01084.vec
# 01084
# sd_GT_usdb_rand01085.csv
# usdb_rand01085.vec
# usdbmil_rand01085.vec
# 01085
# sd_GT_usdb_rand01086.csv
# usdb_rand01086.vec
# usdbmil_rand01086.vec
# 01086
# sd_GT_usdb_rand01087.csv
# usdb_rand01087.vec
# usdbmil_rand01087.vec
# 01087
# sd_GT_usdb_rand01088.csv
# usdb_rand01088.vec
# usdbmil_rand01088.vec
# 01088
# sd_GT_usdb_rand01089.csv
# usdb_rand01089.vec
# usdbmil_rand01089.vec
# 01089
# sd_GT_usdb_rand01090.csv
# usdb_rand01090.vec
# usdbmil_rand01090.vec
# 01090
# sd_GT_usdb_rand01091.csv
# usdb_rand01091.vec
# usdbmil_rand01091.vec
# 01091
# sd_GT_usdb_rand01092.csv
# usdb_rand01092.vec
# usdbmil_rand01092.vec
# 01092
# sd_GT_usdb_rand01093.csv
# usdb_rand01093.vec
# usdbmil_rand01093.vec
# 01093
# sd_GT_usdb_rand01094.csv
# usdb_rand01094.vec
# usdbmil_rand01094.vec
# 01094
# sd_GT_usdb_rand01095.csv
# usdb_rand01095.vec
# usdbmil_rand01095.vec
# 01095
# sd_GT_usdb_rand01096.csv
# usdb_rand01096.vec
# usdbmil_rand01096.vec
# 01096
# sd_GT_usdb_rand01097.csv
# usdb_rand01097.vec
# usdbmil_rand01097.vec
# 01097
# sd_GT_usdb_rand01098.csv
# usdb_rand01098.vec
# usdbmil_rand01098.vec
# 01098
# sd_GT_usdb_rand01099.csv
# usdb_rand01099.vec
# usdbmil_rand01099.vec
# 01099
# sd_GT_usdb_rand01100.csv
# usdb_rand01100.vec
# usdbmil_rand01100.vec
# 01100
# sd_GT_usdb_rand01101.csv
# usdb_rand01101.vec
# usdbmil_rand01101.vec
# 01101
# sd_GT_usdb_rand01102.csv
# usdb_rand01102.vec
# usdbmil_rand01102.vec
# 01102
# sd_GT_usdb_rand01103.csv
# usdb_rand01103.vec
# usdbmil_rand01103.vec
# 01103
# sd_GT_usdb_rand01104.csv
# usdb_rand01104.vec
# usdbmil_rand01104.vec
# 01104
# sd_GT_usdb_rand01105.csv
# usdb_rand01105.vec
# usdbmil_rand01105.vec
# 01105
# sd_GT_usdb_rand01106.csv
# usdb_rand01106.vec
# usdbmil_rand01106.vec
# 01106
#  11%|█         | 107/1000 [00:39<06:01,  2.47it/s]
# sd_GT_usdb_rand01107.csv
# usdb_rand01107.vec
# usdbmil_rand01107.vec
# 01107
# sd_GT_usdb_rand01108.csv
# usdb_rand01108.vec
# usdbmil_rand01108.vec
# 01108
# sd_GT_usdb_rand01109.csv
# usdb_rand01109.vec
# usdbmil_rand01109.vec
# 01109
# sd_GT_usdb_rand01110.csv
# usdb_rand01110.vec
# usdbmil_rand01110.vec
# 01110
#  11%|█         | 111/1000 [00:41<11:22,  1.30it/s]
# sd_GT_usdb_rand01111.csv
# usdb_rand01111.vec
# usdbmil_rand01111.vec
# 01111
# sd_GT_usdb_rand01112.csv
# usdb_rand01112.vec
# usdbmil_rand01112.vec
# 01112
# sd_GT_usdb_rand01113.csv
# usdb_rand01113.vec
# usdbmil_rand01113.vec
# 01113
# sd_GT_usdb_rand01114.csv
# usdb_rand01114.vec
# usdbmil_rand01114.vec
# 01114
# sd_GT_usdb_rand01115.csv
# usdb_rand01115.vec
# usdbmil_rand01115.vec
# 01115
# sd_GT_usdb_rand01116.csv
# usdb_rand01116.vec
# usdbmil_rand01116.vec
# 01116
# sd_GT_usdb_rand01117.csv
# usdb_rand01117.vec
# usdbmil_rand01117.vec
# 01117
# sd_GT_usdb_rand01118.csv
# usdb_rand01118.vec
# usdbmil_rand01118.vec
# 01118
# sd_GT_usdb_rand01119.csv
# usdb_rand01119.vec
# usdbmil_rand01119.vec
# 01119
# sd_GT_usdb_rand01120.csv
# usdb_rand01120.vec
# usdbmil_rand01120.vec
# 01120
#  11%|█         | 112/1000 [00:45<13:21,  1.11it/s]
# sd_GT_usdb_rand01121.csv
# usdb_rand01121.vec
# usdbmil_rand01121.vec
# 01121
# sd_GT_usdb_rand01122.csv
# usdb_rand01122.vec
# usdbmil_rand01122.vec
# 01122
# sd_GT_usdb_rand01123.csv
# usdb_rand01123.vec
# usdbmil_rand01123.vec
# 01123
# sd_GT_usdb_rand01124.csv
# usdb_rand01124.vec
# usdbmil_rand01124.vec
# 01124
# sd_GT_usdb_rand01125.csv
# usdb_rand01125.vec
# usdbmil_rand01125.vec
# 01125
# sd_GT_usdb_rand01126.csv
# usdb_rand01126.vec
# usdbmil_rand01126.vec
# 01126
# sd_GT_usdb_rand01127.csv
# usdb_rand01127.vec
# usdbmil_rand01127.vec
# 01127
# sd_GT_usdb_rand01128.csv
# usdb_rand01128.vec
# usdbmil_rand01128.vec
# 01128
# sd_GT_usdb_rand01129.csv
# usdb_rand01129.vec
# usdbmil_rand01129.vec
# 01129
# sd_GT_usdb_rand01130.csv
# usdb_rand01130.vec
# usdbmil_rand01130.vec
# 01130
# sd_GT_usdb_rand01131.csv
# usdb_rand01131.vec
# usdbmil_rand01131.vec
# 01131
# sd_GT_usdb_rand01132.csv
# usdb_rand01132.vec
# usdbmil_rand01132.vec
# 01132
# sd_GT_usdb_rand01133.csv
# usdb_rand01133.vec
# usdbmil_rand01133.vec
# 01133
# sd_GT_usdb_rand01134.csv
# usdb_rand01134.vec
# usdbmil_rand01134.vec
# 01134
# sd_GT_usdb_rand01135.csv
# usdb_rand01135.vec
# usdbmil_rand01135.vec
# 01135
# sd_GT_usdb_rand01136.csv
# usdb_rand01136.vec
# usdbmil_rand01136.vec
# 01136
# sd_GT_usdb_rand01137.csv
# usdb_rand01137.vec
# usdbmil_rand01137.vec
# 01137
# sd_GT_usdb_rand01138.csv
# usdb_rand01138.vec
# usdbmil_rand01138.vec
# 01138
# sd_GT_usdb_rand01139.csv
# usdb_rand01139.vec
# usdbmil_rand01139.vec
# 01139
# sd_GT_usdb_rand01140.csv
# usdb_rand01140.vec
# usdbmil_rand01140.vec
# 01140
# sd_GT_usdb_rand01141.csv
# usdb_rand01141.vec
# usdbmil_rand01141.vec
# 01141
# sd_GT_usdb_rand01142.csv
# usdb_rand01142.vec
# usdbmil_rand01142.vec
# 01142
# sd_GT_usdb_rand01143.csv
# usdb_rand01143.vec
# usdbmil_rand01143.vec
# 01143
# sd_GT_usdb_rand01144.csv
# usdb_rand01144.vec
# usdbmil_rand01144.vec
# 01144
# sd_GT_usdb_rand01145.csv
# usdb_rand01145.vec
# usdbmil_rand01145.vec
# 01145
# sd_GT_usdb_rand01146.csv
# usdb_rand01146.vec
# usdbmil_rand01146.vec
# 01146
# sd_GT_usdb_rand01147.csv
# usdb_rand01147.vec
# usdbmil_rand01147.vec
# 01147
# sd_GT_usdb_rand01148.csv
# usdb_rand01148.vec
# usdbmil_rand01148.vec
# 01148
# sd_GT_usdb_rand01149.csv
# usdb_rand01149.vec
# usdbmil_rand01149.vec
# 01149
# sd_GT_usdb_rand01150.csv
# usdb_rand01150.vec
# usdbmil_rand01150.vec
# 01150
#  12%|█▏        | 115/1000 [00:56<07:15,  2.03it/s]
# sd_GT_usdb_rand01151.csv
# usdb_rand01151.vec
# usdbmil_rand01151.vec
# 01151
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-15-26ab1b0bcd4b> in <module>
#      24
#      25         try:
# ---> 26             df_dict[run_num_string] = [pd.read_csv(os.path.join(batch_dir,csv_name)),
#      27                                    np.loadtxt(os.path.join(batch_dir,int_vec_name),skiprows=1),
#      28                                    np.loadtxt(os.path.join(batch_dir,mil_vec_name),skiprows=1)]
#
# /usr/workspace/fox39/anaconda3/envs/uq/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# /usr/workspace/fox39/anaconda3/envs/uq/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# /usr/workspace/fox39/anaconda3/envs/uq/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# /usr/workspace/fox39/anaconda3/envs/uq/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# /usr/workspace/fox39/anaconda3/envs/uq/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1896
#    1897         try:
# -> 1898             self._reader = parsers.TextReader(self.handles.handle, **kwds)
#    1899         except Exception:
#    1900             self.handles.close()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
df_dict['00011']
# Out:
# [     Unnamed: 0 parent daughter decay  Zi  Ni  Exi   Ji  ni  Zf  ...  \
#  0             9    20F     20Ne    b-   9  11  0.0    2   1  10  ...
#  1            10    21F     21Ne    b-   9  12  0.0  5/2   1  10  ...
#  2            11    21F     21Ne    b-   9  12  0.0  5/2   1  10  ...
#  3            12    21F     21Ne    b-   9  12  0.0  5/2   1  10  ...
#  4            13    21F     21Ne    b-   9  12  0.0  5/2   1  10  ...
#  ..          ...    ...      ...   ...  ..  ..  ...  ...  ..  ..  ...
#  180         235    35K     35Ar  b+ec  19  16  0.0  3/2   1  18  ...
#  181         236    36K     36Ar  b+ec  19  17  0.0    2   1  18  ...
#  182         237    36K     36Ar  b+ec  19  17  0.0    2   1  18  ...
#  183         238    36K     36Ar  b+ec  19  17  0.0    2   1  18  ...
#  184         239    37K     37Ar  b+ec  19  18  0.0  3/2   1  18  ...
#
#       sigma_logft      Bexp   sigma_B  sigma_B/B  include  twoJi  twoJf  \
#  0         0.0011  0.065901  0.000167   0.002533     True      4      4
#  1         0.0100  0.137592  0.003168   0.023026     True      5      5
#  2         0.1600  0.013140  0.004841   0.368414     True      5      3
#  3         0.0300  0.117110  0.008090   0.069078     True      5      7
#  4         0.0500  0.000477  0.000055   0.115129     True      5      5
#  ..           ...       ...       ...        ...      ...    ...    ...
#  180       0.0500  3.010181  0.346560   0.115129     True      3      3
#  181       0.0400  0.101998  0.009394   0.092103     True      4      4
#  182       0.0600  0.077374  0.010690   0.138155     True      4      4
#  183       0.0500  1.988807  0.228970   0.115129     True      4      4
#  184       0.0030  1.353919  0.009353   0.006908     True      3      3
#
#            Bth  Tmirror  deltaJ
#  0    0.058342    False     0.0
#  1    0.100796    False     0.0
#  2    0.014319    False    -1.0
#  3    0.097263    False     1.0
#  4    0.000292    False     0.0
#  ..        ...      ...     ...
#  180  0.000231    False     0.0
#  181  0.131058    False     0.0
#  182  0.145580    False     0.0
#  183  0.111878    False     0.0
#  184  0.354260     True     0.0
#
#  [185 rows x 27 columns],
#  array([-1.78680482, -1.81491533, -0.04823316, -2.90875087, -0.44869791,
#          0.47702043, -1.20813941, -0.67167225,  0.39244522, -3.22009598,
#          1.9996087 , -1.187556  ,  1.03668334, -0.47862058,  0.08412622,
#         -1.16440483, -0.19723407, -5.67540439,  0.43149183, -4.30972667,
#         -0.1330573 , -1.23505822,  0.75226481, -4.77409655, -1.31835595,
#         -1.71042343, -0.33605138, -0.19876618, -0.40328242, -3.72094827,
#          0.18264917, -2.28533463,  1.42299936, -0.553173  ,  0.31176532,
#         -1.27436136, -0.52923021, -2.07180031, -3.93611942,  0.49928448,
#         -1.85997116, -0.35752943,  0.06655696,  0.84757141, -2.44310909,
#          1.76238728, -0.98287783, -2.48235351, -1.17705302, -1.00331084,
#         -1.76180792, -0.21928946, -4.32531878, -0.99582244, -1.01318763,
#         -1.49292484, -0.48481661, -0.14843014, -0.9385268 , -4.22023153,
#          0.68450747, -1.74603069, -3.74223796,  2.00251379, -3.91340311,
#         -3.16607467]),
#  array([-5.86030745e+00, -1.88888286e+00,  1.16693814e+00, -6.05551784e+00,
#          6.93579394e+00,  3.26769638e+00,  3.46513995e+00,  3.26396537e+00,
#         -2.18893847e+00, -6.31999939e-02, -6.18821156e+00,  1.85147207e+00,
#         -1.88650965e-01, -9.15598293e-01,  6.17103073e-01,  2.18520347e+00,
#         -4.21254113e-01, -2.08984993e-01,  5.36830481e-01, -1.30275270e+00,
#         -1.72142439e+00, -8.69805198e-01, -5.11458139e-01,  1.38678792e+00,
#          2.13379065e+00, -6.74508904e-01,  7.11604272e-02,  2.71611621e-02,
#         -5.65550233e-01,  7.63041129e-01, -1.02000149e+00,  2.52431406e-04,
#          1.31694753e+00,  1.63591444e+00,  8.25508548e-01,  2.64798101e-01,
#         -2.23143096e-01,  2.98510518e-01,  1.67115945e-01, -1.56285134e+00,
#          1.06601463e-03, -1.95119267e-01,  1.10001879e-01,  9.61087885e-01,
#          1.23022659e+00,  1.06439996e+00,  1.08459718e+00,  1.62681008e+00,
#          1.35875663e+00,  9.17349290e-01, -3.55954387e-01, -6.97677813e-01,
#          6.94879642e-01, -6.83364402e-01, -5.53096755e-01,  1.17251437e+00,
#         -5.70120772e-02, -3.17580138e+00,  4.94632274e-01,  2.70511485e-01,
#          1.09905736e+00, -8.73319729e-02,  1.37108850e+00, -2.70610413e+00,
#         -9.40555838e-01, -2.68690451e+00])]

# %%
df_dict = {}
for run_dir in tqdm(run_dir_list):
    run_num_string = run_dir.split('rand')[-1]
    df_dict[run_num_string] = [pd.read_csv(os.path.join(run_dir,f'sd_GT_usdb_rand{run_num_string}_complete.csv')), 
                               np.loadtxt(os.path.join(run_dir,f'usdb_rand{run_num_string}.vec'),skiprows=1), 
                               np.loadtxt(os.path.join(run_dir,f'usdbmil_rand{run_num_string}.vec'),skiprows=1)]
# Out:
# 100%|██████████| 9999/9999 [1:03:08<00:00,  2.64it/s]

# %%
with open('gt_results_10k_070422.pkl','wb') as fh:
    pkl.dump(df_dict,fh)
# with open('gt_results_10k_210222.pkl','rb') as fh:
#     [df_dict,int_vec_array,mil_vec_array] = pkl.load(fh)
